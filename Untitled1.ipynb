# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_id = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 1172, in _get_module
#     value = self._get_module(name)
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/transformers/models/llama/tokenization_llama_fast.py", line 32, in <module>
#     from .tokenization_llama import LlamaTokenizer
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/transformers/models/llama/tokenization_llama.py", line 28, in <module>
#     from ...convert_slow_tokenizer import import_protobuf
# ImportError: cannot import name 'import_protobuf' from 'transformers.convert_slow_tokenizer' (/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/transformers/convert_slow_tokenizer.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_78014/2862562967.py", line 4, in <module>
#     tokenizer = AutoTokenizer.from_pretrained(model_id)
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/transformers/models/auto/tokenization_auto.py", line 684, in from_pretrained
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/transformers/models/auto/tokenization_auto.py", line 395, in tokenizer_class_from_name
#     (
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 1162, in __getattr__
#     # they have been accessed or not. So we only add the elements of self.__all__ that are not already in the dir.
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 1174, in _get_module
#     module = self._get_module(self._class_to_module[name])
# RuntimeError: Failed to import transformers.models.llama.tokenization_llama_fast because of the following error (look up to see its traceback):
# cannot import name 'import_protobuf' from 'transformers.convert_slow_tokenizer' (/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/transformers/convert_slow_tokenizer.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2102, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1310, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1199, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1052, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/IPython/core/ultratb.py", line 978, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/IPython/core/ultratb.py", line 878, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/IPython/core/ultratb.py", line 712, in lines
#     return self._sd.lines
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
AutoModelForCausalLM.from_pretrained?

# %%
! pip install auto-gptq
# Out:
# Collecting auto-gptq
#   Downloading auto_gptq-0.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: datasets in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from auto-gptq) (2.13.1)
# Collecting safetensors
#   Downloading safetensors-0.3.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.9 MB/s eta 0:00:00a 0:00:01
# Collecting rouge
#   Using cached rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: accelerate>=0.19.0 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from auto-gptq) (0.19.0)
# Collecting transformers>=4.31.0
#   Downloading transformers-4.33.1-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 6.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from auto-gptq) (1.23.5)
# Collecting peft
#   Downloading peft-0.5.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from auto-gptq) (2.0.1)
# Requirement already satisfied: psutil in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from accelerate>=0.19.0->auto-gptq) (5.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/gary/.local/lib/python3.9/site-packages (from accelerate>=0.19.0->auto-gptq) (23.0)
# Requirement already satisfied: pyyaml in /home/gary/.local/lib/python3.9/site-packages (from accelerate>=0.19.0->auto-gptq) (6.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (11.10.3.66)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (2.14.3)
# Requirement already satisfied: typing-extensions in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (4.7.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (11.7.101)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (11.7.99)
# Requirement already satisfied: triton==2.0.0 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (2.0.0)
# Requirement already satisfied: filelock in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (3.12.0)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (10.9.0.58)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (11.7.4.91)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (11.7.91)
# Requirement already satisfied: networkx in /home/gary/.local/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (2.6.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (11.7.99)
# Requirement already satisfied: jinja2 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (3.1.2)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (8.5.0.96)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (10.2.10.91)
# Requirement already satisfied: sympy in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from torch>=1.13.0->auto-gptq) (1.11.1)
# Requirement already satisfied: setuptools in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->auto-gptq) (67.8.0)
# Requirement already satisfied: wheel in /home/gary/.local/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->auto-gptq) (0.38.4)
# Requirement already satisfied: cmake in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.13.0->auto-gptq) (3.26.3)
# Requirement already satisfied: lit in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.13.0->auto-gptq) (16.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from transformers>=4.31.0->auto-gptq) (2023.3.23)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from transformers>=4.31.0->auto-gptq) (0.13.3)
# Collecting huggingface-hub<1.0,>=0.15.1
#   Using cached huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
# Requirement already satisfied: tqdm>=4.27 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from transformers>=4.31.0->auto-gptq) (4.65.0)
# Requirement already satisfied: requests in /home/gary/.local/lib/python3.9/site-packages (from transformers>=4.31.0->auto-gptq) (2.28.2)
# Requirement already satisfied: multiprocess in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from datasets->auto-gptq) (0.70.14)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from datasets->auto-gptq) (12.0.1)
# Requirement already satisfied: pandas in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from datasets->auto-gptq) (2.0.2)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from datasets->auto-gptq) (0.3.6)
# Requirement already satisfied: xxhash in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from datasets->auto-gptq) (3.2.0)
# Requirement already satisfied: aiohttp in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from datasets->auto-gptq) (3.8.4)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from datasets->auto-gptq) (2023.5.0)
# Requirement already satisfied: six in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from aiohttp->datasets->auto-gptq) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from aiohttp->datasets->auto-gptq) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from aiohttp->datasets->auto-gptq) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/gary/.local/lib/python3.9/site-packages (from aiohttp->datasets->auto-gptq) (3.0.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from aiohttp->datasets->auto-gptq) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from aiohttp->datasets->auto-gptq) (22.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gary/.local/lib/python3.9/site-packages (from requests->transformers>=4.31.0->auto-gptq) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/gary/.local/lib/python3.9/site-packages (from requests->transformers>=4.31.0->auto-gptq) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from requests->transformers>=4.31.0->auto-gptq) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from pandas->datasets->auto-gptq) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gary/.local/lib/python3.9/site-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from pandas->datasets->auto-gptq) (2022.7)
# Requirement already satisfied: mpmath>=0.19 in /home/gary/miniconda3/envs/huggingface/lib/python3.9/site-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Installing collected packages: safetensors, rouge, huggingface-hub, transformers, peft, auto-gptq
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.14.1
#     Uninstalling huggingface-hub-0.14.1:
#       Successfully uninstalled huggingface-hub-0.14.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.29.2
#     Uninstalling transformers-4.29.2:
#       Successfully uninstalled transformers-4.29.2
# Successfully installed auto-gptq-0.4.2 huggingface-hub-0.16.4 peft-0.5.0 rouge-1.0.1 safetensors-0.3.3 transformers-4.33.1
